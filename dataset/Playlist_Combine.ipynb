# %%
import glob
import os
import pandas as pd



folder_name = r"C:\Users\ROSHAN\Titofy\Data"
file_type = 'csv'
seperator =','
dataframe = pd.concat([pd.read_csv(f, sep=seperator,encoding= 'unicode_escape') for f in glob.glob(folder_name + "/*."+file_type)],ignore_index=True)

# %%
dataframe.shape
# Out:
# (5147, 21)

# %%
dataframe.columns
# Out:
# Index(['Playlist_Name', 'Username', 'Track_Title', 'Track_ID', 'Artist',
#        'Duration_ms', 'Popularity', 'Explicit', 'Album', 'Release_Date',
#        'Label', 'Danceability', 'Energy', 'Key', 'Loudness', 'Speechiness',
#        'Acousticness', 'Instrumentalness', 'Liveness', 'Tempo',
#        'Time_Signature'],
#       dtype='object')

# %%
dataframe['Username'].value_counts()
# Out:
# Srujai Varikuti              462
# Joohee                       346
# Jayant Benjamin              327
# Bhallaboy                    233
# Akshita Vaidya               230
# Rohan.Muj                    189
# fthdx9hb3u2t3knrq3fsic01y    188
# Yorke                        169
# Abhishek Yerra               164
# Samridhi Diwan               160
# Smruthi                      151
# Tye Copes                    150
# bsj7ilxbmjjqgd7wz89ogtug1    142
# Sahil Rao                    122
# Subha Karanam                120
# Anshuman                     118
# fridonora                    113
# Niyati Jain                  111
# Abbs Soltani                 109
# ircatokft78qqfhr7dpe325x0    108
# Anvay Gumaste                103
# Slavvy Coelho                100
# Swapnil Kadam                 92
# Mahima Narayan                89
# Surabhi Shrivastava           81
# Ralaperher                    74
# Pratyaksha                    72
# pansy                         70
# ...

# %%
dataframe
# Out:
#               Playlist_Name         Username                Track_Title  \
# 0     Pathetically inspired  Hri7ik Barthwal     I Could Never Be Loved
# 1     Pathetically inspired  Hri7ik Barthwal              Do You Wonder
# 2     Pathetically inspired  Hri7ik Barthwal              Please Notice
# 3     Pathetically inspired  Hri7ik Barthwal  Another One of Those Days
# 4     Pathetically inspired  Hri7ik Barthwal   slow dancing in the dark
# ...                     ...              ...                        ...
# 5142                   noah   Mahima Narayan           I Like Me Better
# 5143                   noah   Mahima Narayan                    You & I
# 5144                   noah   Mahima Narayan                     REMEDY
# 5145                   noah   Mahima Narayan                  Right Now
# 5146                   noah   Mahima Narayan               Lucky Strike
#
#                     Track_ID           Artist Duration_ms Popularity Explicit  \
# ...

# %%
 dataframe.drop_duplicates(subset=['Track_ID'] , inplace = True)

# %%
dataframe.shape
# Out:
# (4454, 21)

# %%
dataframe = dataframe[dataframe["Tempo"] != "Tempo"]

# %%
print(dataframe[dataframe['Tempo']=='Tempo'].index.values)
# Out:
# []

# %%
from sklearn.preprocessing import MinMaxScaler

def get_mean(df):
    
   
    

    scaler = MinMaxScaler()

    data = df[['Popularity', 'Danceability','Energy', 'Key', 'Loudness', 'Speechiness',
       'Acousticness', 'Instrumentalness', 'Liveness', 'Tempo']]

    df[['Popularity', 'Danceability','Energy', 'Key', 'Loudness', 'Speechiness',
       'Acousticness', 'Instrumentalness', 'Liveness', 'Tempo']] = scaler.fit_transform(df[['Popularity', 'Danceability','Energy', 'Key', 'Loudness', 'Speechiness',
       'Acousticness', 'Instrumentalness', 'Liveness', 'Tempo']])

    list1 = list(df.mean(axis=0))
    
    avg_features_df = pd.DataFrame(data = list1 , index = ['Popularity', 'Danceability','Energy', 'Key', 'Loudness', 'Speechiness',
       'Acousticness', 'Instrumentalness', 'Liveness', 'Tempo'])
    
    
    
    avg_features_df = avg_features_df.transpose()

    #avg_features_df.drop(['Duration_ms','Explicit','Time_Signature'] , axis = 1,inplace = True)
    
    avg_features_df.to_csv('Average.csv', index = False)
    
    return avg_features_df


get_mean(dataframe)
# Out:
# C:\Users\ROSHAN\Anaconda3\lib\site-packages\ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   from ipykernel import kernelapp as app
# C:\Users\ROSHAN\Anaconda3\lib\site-packages\pandas\core\frame.py:2969: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.loc._setitem_with_indexer((slice(None), indexer), value)
# C:\Users\ROSHAN\Anaconda3\lib\site-packages\pandas\core\frame.py:2935: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
dataframe.to_csv('Combined.csv' , index = False)

# %%
s= pd.read_csv(r'C:\Users\ROSHAN\Titofy\Combined.csv' , encoding= 'unicode_escape')

# %%
s.head()
# Out:
#            Playlist_Name         Username                Track_Title  \
# 0  Pathetically inspired  Hri7ik Barthwal     I Could Never Be Loved
# 1  Pathetically inspired  Hri7ik Barthwal              Do You Wonder
# 2  Pathetically inspired  Hri7ik Barthwal              Please Notice
# 3  Pathetically inspired  Hri7ik Barthwal  Another One of Those Days
# 4  Pathetically inspired  Hri7ik Barthwal   slow dancing in the dark
#
#                  Track_ID           Artist  Duration_ms  Popularity  Explicit  \
# 0  2c9iVAV8Vte2POKrVZFC02            Powfu       213942    0.663265     False
# 1  08zeEYblrLGAwATpniIMCu      khai dreams       147428    0.081633     False
# 2  36seMHoyXmLUNxcwzwjdF7  Christian Leave       116666    0.724490     False
# 3  3EE00p7Slt5bWFr2cSQgrs         Cavetown       246041    0.571429     False
# 4  3nsE1k6l1BRI1nVz6NOint         sora.wav       204042    0.540816      True
#
#                       Album Release_Date  ... Danceability    Energy  \
# ...

# %%
s.shape
# Out:
# (4453, 21)
